# %%
import json

# %%
with open("public/stress-performance/assets/data/orders.json", 'r') as fdata:
    data = json.load(fdata)
data
# Out:
# {'1': {'10': ['SPL_Stimuli/n10-1/Images/n10-1A-drawing-0.4.png',
#    'SPL_Stimuli/n10-1/Images/n10-1B-drawing-0.45.png',
#    'SPL_Stimuli/n10-1/Images/n10-1C-drawing-0.5.png',
#    'SPL_Stimuli/n10-2/Images/n10-2A-drawing-0.55.png',
#    'SPL_Stimuli/n10-2/Images/n10-2B-drawing-0.6.png',
#    'SPL_Stimuli/n10-2/Images/n10-2C-drawing-0.65.png',
#    'SPL_Stimuli/n10-3/Images/n10-3A-drawing-0.7.png',
#    'SPL_Stimuli/n10-3/Images/n10-3forB-drawing-0.75.png',
#    'SPL_Stimuli/n10-3/Images/n10-3C-drawing-0.8.png'],
#   '25': ['SPL_Stimuli/n25-1/Images/n25-1A-drawing-0.4.png',
#    'SPL_Stimuli/n25-1/Images/n25-1B-drawing-0.45.png',
#    'SPL_Stimuli/n25-1/Images/n25-1C-drawing-0.5.png',
#    'SPL_Stimuli/n25-2/Images/n25-2A-drawing-0.55.png',
#    'SPL_Stimuli/n25-2/Images/n25-2B-drawing-0.6.png',
#    'SPL_Stimuli/n25-2/Images/n25-2C-drawing-0.65.png',
#    'SPL_Stimuli/n25-3/Images/n25-3A-drawing-0.7.png',
#    'SPL_Stimuli/n25-3/Images/n25-3B-drawing-0.75.png',
#    'SPL_Stimuli/n25-3/Images/n25-3C-drawing-0.8.png'],
#   '50': ['SPL_Stimuli/n50-1/Images/n50-1A-drawing-0.4.png',
#    'SPL_Stimuli/n50-1/Images/n50-1B-drawing-0.45.png',
#    'SPL_Stimuli/n50-1/Images/n50-1C-drawing-0.5.png',
#    'SPL_Stimuli/n50-2/Images/n50-2A-drawing-0.55.png',
#    'SPL_Stimuli/n50-2/Images/n50-2B-drawing-0.6.png',
#    'SPL_Stimuli/n50-2/Images/n50-2C-drawing-0.65.png',
#    'SPL_Stimuli/n50-3/Images/n50-3A-drawing-0.7.png',
#    'SPL_Stimuli/n50-3/Images/n50-3B-drawing-0.75.png',
#    'SPL_Stimuli/n50-3/Images/n50-3C-drawing-0.8.png']},
#  '2': {'10': ['SPL_Stimuli/n10-1/Images/n10-1A-drawing-0.45.png',
#    'SPL_Stimuli/n10-1/Images/n10-1B-drawing-0.5.png',
#    'SPL_Stimuli/n10-1/Images/n10-1C-drawing-0.55.png',
#    'SPL_Stimuli/n10-2/Images/n10-2A-drawing-0.6.png',
#    'SPL_Stimuli/n10-2/Images/n10-2B-drawing-0.65.png',
#    'SPL_Stimuli/n10-2/Images/n10-2C-drawing-0.7.png',
#    'SPL_Stimuli/n10-3/Images/n10-3A-drawing-0.75.png',
#    'SPL_Stimuli/n10-3/Images/n10-3B-drawing-0.8.png',
#    'SPL_Stimuli/n10-3/Images/n10-3C-drawing-0.4.png'],
#   '25': ['SPL_Stimuli/n25-1/Images/n25-1A-drawing-0.45.png',
#    'SPL_Stimuli/n25-1/Images/n25-1B-drawing-0.5.png',
#    'SPL_Stimuli/n25-1/Images/n25-1C-drawing-0.55.png',
#    'SPL_Stimuli/n25-2/Images/n25-2A-drawing-0.6.png',
#    'SPL_Stimuli/n25-2/Images/n25-2B-drawing-0.65.png',
#    'SPL_Stimuli/n25-2/Images/n25-2C-drawing-0.7.png',
#    'SPL_Stimuli/n25-3/Images/n25-3A-drawing-0.75.png',
#    'SPL_Stimuli/n25-3/Images/n25-3B-drawing-0.8.png',
#    'SPL_Stimuli/n25-3/Images/n25-3C-drawing-0.4.png'],
#   '50': ['SPL_Stimuli/n50-1/Images/n50-1A-drawing-0.45.png',
#    'SPL_Stimuli/n50-1/Images/n50-1B-drawing-0.5.png',
#    'SPL_Stimuli/n50-1/Images/n50-1C-drawing-0.55.png',
#    'SPL_Stimuli/n50-2/Images/n50-2A-drawing-0.6.png',
#    'SPL_Stimuli/n50-2/Images/n50-2B-drawing-0.65.png',
#    'SPL_Stimuli/n50-2/Images/n50-2C-drawing-0.7.png',
#    'SPL_Stimuli/n50-3/Images/n50-3A-drawing-0.75.png',
#    'SPL_Stimuli/n50-3/Images/n50-3B-drawing-0.8.png',
#    'SPL_Stimuli/n50-3/Images/n50-3C-drawing-0.4.png']},
#  '3': {'10': ['SPL_Stimuli/n10-1/Images/n10-1A-drawing-0.5.png',
#    'SPL_Stimuli/n10-1/Images/n10-1B-drawing-0.55.png',
#    'SPL_Stimuli/n10-1/Images/n10-1C-drawing-0.6.png',
#    'SPL_Stimuli/n10-2/Images/n10-2A-drawing-0.65.png',
#    'SPL_Stimuli/n10-2/Images/n10-2B-drawing-0.7.png',
#    'SPL_Stimuli/n10-2/Images/n10-2C-drawing-0.75.png',
#    'SPL_Stimuli/n10-3/Images/n10-3A-drawing-0.8.png',
#    'SPL_Stimuli/n10-3/Images/n10-3B-drawing-0.4.png',
#    'SPL_Stimuli/n10-3/Images/n10-3C-drawing-0.45.png'],
#   '25': ['SPL_Stimuli/n25-1/Images/n25-1A-drawing-0.5.png',
#    'SPL_Stimuli/n25-1/Images/n25-1B-drawing-0.55.png',
#    'SPL_Stimuli/n25-1/Images/n25-1C-drawing-0.6.png',
#    'SPL_Stimuli/n25-2/Images/n25-2A-drawing-0.65.png',
#    'SPL_Stimuli/n25-2/Images/n25-2B-drawing-0.7.png',
#    'SPL_Stimuli/n25-2/Images/n25-2C-drawing-0.75.png',
#    'SPL_Stimuli/n25-3/Images/n25-3A-drawing-0.8.png',
#    'SPL_Stimuli/n25-3/Images/n25-3B-drawing-0.4.png',
#    'SPL_Stimuli/n25-3/Images/n25-3C-drawing-0.45.png'],
#   '50': ['SPL_Stimuli/n50-1/Images/n50-1A-drawing-0.5.png',
#    'SPL_Stimuli/n50-1/Images/n50-1B-drawing-0.55.png',
#    'SPL_Stimuli/n50-1/Images/n50-1C-drawing-0.6.png',
#    'SPL_Stimuli/n50-2/Images/n50-2A-drawing-0.65.png',
#    'SPL_Stimuli/n50-2/Images/n50-2B-drawing-0.7.png',
#    'SPL_Stimuli/n50-2/Images/n50-2C-drawing-0.75.png',
#    'SPL_Stimuli/n50-3/Images/n50-3A-drawing-0.8.png',
#    'SPL_Stimuli/n50-3/Images/n50-3B-drawing-0.4.png',
#    'SPL_Stimuli/n50-3/Images/n50-3C-drawing-0.45.png']},
#  '4': {'10': ['SPL_Stimuli/n10-1/Images/n10-1A-drawing-0.55.png',
#    'SPL_Stimuli/n10-1/Images/n10-1B-drawing-0.6.png',
#    'SPL_Stimuli/n10-1/Images/n10-1C-drawing-0.65.png',
#    'SPL_Stimuli/n10-2/Images/n10-2A-drawing-0.7.png',
#    'SPL_Stimuli/n10-2/Images/n10-2B-drawing-0.75.png',
#    'SPL_Stimuli/n10-2/Images/n10-2C-drawing-0.8.png',
#    'SPL_Stimuli/n10-3/Images/n10-3A-drawing-0.4.png',
#    'SPL_Stimuli/n10-3/Images/n10-3B-drawing-0.45.png',
#    'SPL_Stimuli/n10-3/Images/n10-3C-drawing-0.5.png'],
#   '25': ['SPL_Stimuli/n25-1/Images/n25-1A-drawing-0.55.png',
#    'SPL_Stimuli/n25-1/Images/n25-1B-drawing-0.6.png',
#    'SPL_Stimuli/n25-1/Images/n25-1C-drawing-0.65.png',
#    'SPL_Stimuli/n25-2/Images/n25-2A-drawing-0.7.png',
#    'SPL_Stimuli/n25-2/Images/n25-2B-drawing-0.75.png',
#    'SPL_Stimuli/n25-2/Images/n25-2C-drawing-0.8.png',
#    'SPL_Stimuli/n25-3/Images/n25-3A-drawing-0.4.png',
#    'SPL_Stimuli/n25-3/Images/n25-3B-drawing-0.45.png',
#    'SPL_Stimuli/n25-3/Images/n25-3C-drawing-0.5.png'],
#   '50': ['SPL_Stimuli/n50-1/Images/n50-1A-drawing-0.55.png',
#    'SPL_Stimuli/n50-1/Images/n50-1B-drawing-0.6.png',
#    'SPL_Stimuli/n50-1/Images/n50-1C-drawing-0.65.png',
#    'SPL_Stimuli/n50-2/Images/n50-2A-drawing-0.7.png',
#    'SPL_Stimuli/n50-2/Images/n50-2B-drawing-0.75.png',
#    'SPL_Stimuli/n50-2/Images/n50-2C-drawing-0.8.png',
#    'SPL_Stimuli/n50-3/Images/n50-3A-drawing-0.4.png',
#    'SPL_Stimuli/n50-3/Images/n50-3B-drawing-0.45.png',
#    'SPL_Stimuli/n50-3/Images/n50-3C-drawing-0.5.png']},
#  '5': {'10': ['SPL_Stimuli/n10-1/Images/n10-1A-drawing-0.6.png',
#    'SPL_Stimuli/n10-1/Images/n10-1B-drawing-0.65.png',
#    'SPL_Stimuli/n10-1/Images/n10-1C-drawing-0.7.png',
#    'SPL_Stimuli/n10-2/Images/n10-2A-drawing-0.75.png',
#    'SPL_Stimuli/n10-2/Images/n10-2B-drawing-0.8.png',
#    'SPL_Stimuli/n10-2/Images/n10-2C-drawing-0.4.png',
#    'SPL_Stimuli/n10-3/Images/n10-3A-drawing-0.45.png',
#    'SPL_Stimuli/n10-3/Images/n10-3B-drawing-0.5.png',
#    'SPL_Stimuli/n10-3/Images/n10-3C-drawing-0.55.png'],
#   '25': ['SPL_Stimuli/n25-1/Images/n25-1A-drawing-0.6.png',
#    'SPL_Stimuli/n25-1/Images/n25-1B-drawing-0.65.png',
#    'SPL_Stimuli/n25-1/Images/n25-1C-drawing-0.7.png',
#    'SPL_Stimuli/n25-2/Images/n25-2A-drawing-0.75.png',
#    'SPL_Stimuli/n25-2/Images/n25-2B-drawing-0.8.png',
#    'SPL_Stimuli/n25-2/Images/n25-2C-drawing-0.4.png',
#    'SPL_Stimuli/n25-3/Images/n25-3A-drawing-0.45.png',
#    'SPL_Stimuli/n25-3/Images/n25-3B-drawing-0.5.png',
#    'SPL_Stimuli/n25-3/Images/n25-3C-drawing-0.55.png'],
#   '50': ['SPL_Stimuli/n50-1/Images/n50-1A-drawing-0.6.png',
#    'SPL_Stimuli/n50-1/Images/n50-1B-drawing-0.65.png',
#    'SPL_Stimuli/n50-1/Images/n50-1C-drawing-0.7.png',
#    'SPL_Stimuli/n50-2/Images/n50-2A-drawing-0.75.png',
#    'SPL_Stimuli/n50-2/Images/n50-2B-drawing-0.8.png',
#    'SPL_Stimuli/n50-2/Images/n50-2C-drawing-0.4.png',
#    'SPL_Stimuli/n50-3/Images/n50-3A-drawing-0.45.png',
#    'SPL_Stimuli/n50-3/Images/n50-3B-drawing-0.5.png',
#    'SPL_Stimuli/n50-3/Images/n50-3C-drawing-0.55.png']},
#  '6': {'10': ['SPL_Stimuli/n10-1/Images/n10-1A-drawing-0.65.png',
#    'SPL_Stimuli/n10-1/Images/n10-1B-drawing-0.7.png',
#    'SPL_Stimuli/n10-1/Images/n10-1C-drawing-0.75.png',
#    'SPL_Stimuli/n10-2/Images/n10-2A-drawing-0.8.png',
#    'SPL_Stimuli/n10-2/Images/n10-2B-drawing-0.4.png',
#    'SPL_Stimuli/n10-2/Images/n10-2C-drawing-0.45.png',
#    'SPL_Stimuli/n10-3/Images/n10-3A-drawing-0.5.png',
#    'SPL_Stimuli/n10-3/Images/n10-3B-drawing-0.55.png',
#    'SPL_Stimuli/n10-3/Images/n10-3C-drawing-0.6.png'],
#   '25': ['SPL_Stimuli/n25-1/Images/n25-1A-drawing-0.65.png',
#    'SPL_Stimuli/n25-1/Images/n25-1B-drawing-0.7.png',
#    'SPL_Stimuli/n25-1/Images/n25-1C-drawing-0.75.png',
#    'SPL_Stimuli/n25-2/Images/n25-2A-drawing-0.8.png',
#    'SPL_Stimuli/n25-2/Images/n25-2B-drawing-0.4.png',
#    'SPL_Stimuli/n25-2/Images/n25-2C-drawing-0.45.png',
#    'SPL_Stimuli/n25-3/Images/n25-3A-drawing-0.5.png',
#    'SPL_Stimuli/n25-3/Images/n25-3B-drawing-0.55.png',
#    'SPL_Stimuli/n25-3/Images/n25-3C-drawing-0.6.png'],
#   '50': ['SPL_Stimuli/n50-1/Images/n50-1A-drawing-0.65.png',
#    'SPL_Stimuli/n50-1/Images/n50-1B-drawing-0.7.png',
#    'SPL_Stimuli/n50-1/Images/n50-1C-drawing-0.75.png',
#    'SPL_Stimuli/n50-2/Images/n50-2A-drawing-0.8.png',
#    'SPL_Stimuli/n50-2/Images/n50-2B-drawing-0.4.png',
#    'SPL_Stimuli/n50-2/Images/n50-2C-drawing-0.45.png',
#    'SPL_Stimuli/n50-3/Images/n50-3A-drawing-0.5.png',
#    'SPL_Stimuli/n50-3/Images/n50-3B-drawing-0.55.png',
#    'SPL_Stimuli/n50-3/Images/n50-3C-drawing-0.6.png']},
#  '7': {'10': ['SPL_Stimuli/n10-1/Images/n10-1A-drawing-0.7.png',
#    'SPL_Stimuli/n10-1/Images/n10-1B-drawing-0.75.png',
#    'SPL_Stimuli/n10-1/Images/n10-1C-drawing-0.8.png',
#    'SPL_Stimuli/n10-2/Images/n10-2A-drawing-0.4.png',
#    'SPL_Stimuli/n10-2/Images/n10-2B-drawing-0.45.png',
#    'SPL_Stimuli/n10-2/Images/n10-2C-drawing-0.5.png',
#    'SPL_Stimuli/n10-3/Images/n10-3A-drawing-0.55.png',
#    'SPL_Stimuli/n10-3/Images/n10-3B-drawing-0.6.png',
#    'SPL_Stimuli/n10-3/Images/n10-3C-drawing-0.65.png'],
#   '25': ['SPL_Stimuli/n25-1/Images/n25-1A-drawing-0.7.png',
#    'SPL_Stimuli/n25-1/Images/n25-1B-drawing-0.75.png',
#    'SPL_Stimuli/n25-1/Images/n25-1C-drawing-0.8.png',
#    'SPL_Stimuli/n25-2/Images/n25-2A-drawing-0.4.png',
#    'SPL_Stimuli/n25-2/Images/n25-2B-drawing-0.45.png',
#    'SPL_Stimuli/n25-2/Images/n25-2C-drawing-0.5.png',
#    'SPL_Stimuli/n25-3/Images/n25-3A-drawing-0.55.png',
#    'SPL_Stimuli/n25-3/Images/n25-3B-drawing-0.6.png',
#    'SPL_Stimuli/n25-3/Images/n25-3C-drawing-0.65.png'],
#   '50': ['SPL_Stimuli/n50-1/Images/n50-1A-drawing-0.7.png',
#    'SPL_Stimuli/n50-1/Images/n50-1B-drawing-0.75.png',
#    'SPL_Stimuli/n50-1/Images/n50-1C-drawing-0.8.png',
#    'SPL_Stimuli/n50-2/Images/n50-2A-drawing-0.4.png',
#    'SPL_Stimuli/n50-2/Images/n50-2B-drawing-0.45.png',
#    'SPL_Stimuli/n50-2/Images/n50-2C-drawing-0.5.png',
#    'SPL_Stimuli/n50-3/Images/n50-3A-drawing-0.55.png',
#    'SPL_Stimuli/n50-3/Images/n50-3B-drawing-0.6.png',
#    'SPL_Stimuli/n50-3/Images/n50-3C-drawing-0.65.png']},
#  '8': {'10': ['SPL_Stimuli/n10-1/Images/n10-1A-drawing-0.75.png',
#    'SPL_Stimuli/n10-1/Images/n10-1B-drawing-0.8.png',
#    'SPL_Stimuli/n10-1/Images/n10-1C-drawing-0.4.png',
#    'SPL_Stimuli/n10-2/Images/n10-2A-drawing-0.45.png',
#    'SPL_Stimuli/n10-2/Images/n10-2B-drawing-0.5.png',
#    'SPL_Stimuli/n10-2/Images/n10-2C-drawing-0.55.png',
#    'SPL_Stimuli/n10-3/Images/n10-3A-drawing-0.6.png',
#    'SPL_Stimuli/n10-3/Images/n10-3B-drawing-0.65.png',
#    'SPL_Stimuli/n10-3/Images/n10-3C-drawing-0.7.png'],
#   '25': ['SPL_Stimuli/n25-1/Images/n25-1A-drawing-0.75.png',
#    'SPL_Stimuli/n25-1/Images/n25-1B-drawing-0.8.png',
#    'SPL_Stimuli/n25-1/Images/n25-1C-drawing-0.4.png',
#    'SPL_Stimuli/n25-2/Images/n25-2A-drawing-0.45.png',
#    'SPL_Stimuli/n25-2/Images/n25-2B-drawing-0.5.png',
#    'SPL_Stimuli/n25-2/Images/n25-2C-drawing-0.55.png',
#    'SPL_Stimuli/n25-3/Images/n25-3A-drawing-0.6.png',
#    'SPL_Stimuli/n25-3/Images/n25-3B-drawing-0.65.png',
#    'SPL_Stimuli/n25-3/Images/n25-3C-drawing-0.7.png'],
#   '50': ['SPL_Stimuli/n50-1/Images/n50-1A-drawing-0.75.png',
#    'SPL_Stimuli/n50-1/Images/n50-1B-drawing-0.8.png',
#    'SPL_Stimuli/n50-1/Images/n50-1C-drawing-0.4.png',
#    'SPL_Stimuli/n50-2/Images/n50-2A-drawing-0.45.png',
#    'SPL_Stimuli/n50-2/Images/n50-2B-drawing-0.5.png',
#    'SPL_Stimuli/n50-2/Images/n50-2C-drawing-0.55.png',
#    'SPL_Stimuli/n50-3/Images/n50-3A-drawing-0.6.png',
#    'SPL_Stimuli/n50-3/Images/n50-3B-drawing-0.65.png',
#    'SPL_Stimuli/n50-3/Images/n50-3C-drawing-0.7.png']},
#  '9': {'10': ['SPL_Stimuli/n10-1/Images/n10-1A-drawing-0.8.png',
#    'SPL_Stimuli/n10-1/Images/n10-1B-drawing-0.4.png',
#    'SPL_Stimuli/n10-1/Images/n10-1C-drawing-0.45.png',
#    'SPL_Stimuli/n10-2/Images/n10-2A-drawing-0.5.png',
#    'SPL_Stimuli/n10-2/Images/n10-2B-drawing-0.55.png',
#    'SPL_Stimuli/n10-2/Images/n10-2C-drawing-0.6.png',
#    'SPL_Stimuli/n10-3/Images/n10-3A-drawing-0.65.png',
#    'SPL_Stimuli/n10-3/Images/n10-3B-drawing-0.7.png',
#    'SPL_Stimuli/n10-3/Images/n10-3C-drawing-0.75.png'],
#   '25': ['SPL_Stimuli/n25-1/Images/n25-1A-drawing-0.8.png',
#    'SPL_Stimuli/n25-1/Images/n25-1B-drawing-0.4.png',
#    'SPL_Stimuli/n25-1/Images/n25-1C-drawing-0.45.png',
#    'SPL_Stimuli/n25-2/Images/n25-2A-drawing-0.5.png',
#    'SPL_Stimuli/n25-2/Images/n25-2B-drawing-0.55.png',
#    'SPL_Stimuli/n25-2/Images/n25-2C-drawing-0.6.png',
#    'SPL_Stimuli/n25-3/Images/n25-3A-drawing-0.65.png',
#    'SPL_Stimuli/n25-3/Images/n25-3B-drawing-0.7.png',
#    'SPL_Stimuli/n25-3/Images/n25-3C-drawing-0.75.png'],
#   '50': ['SPL_Stimuli/n50-1/Images/n50-1A-drawing-0.8.png',
#    'SPL_Stimuli/n50-1/Images/n50-1B-drawing-0.4.png',
#    'SPL_Stimuli/n50-1/Images/n50-1C-drawing-0.45.png',
#    'SPL_Stimuli/n50-2/Images/n50-2A-drawing-0.5.png',
#    'SPL_Stimuli/n50-2/Images/n50-2B-drawing-0.55.png',
#    'SPL_Stimuli/n50-2/Images/n50-2C-drawing-0.6.png',
#    'SPL_Stimuli/n50-3/Images/n50-3A-drawing-0.65.png',
#    'SPL_Stimuli/n50-3/Images/n50-3B-drawing-0.7.png',
#    'SPL_Stimuli/n50-3/Images/n50-3C-drawing-0.75.png']}}

# %%
Config = dict()
Config['order'] = 'latinSquare'
Config['numSamples'] = 1 
Config['components'] = list()

# %%
Config['components'] = [dict() for i in range(9) ]

# %%
Config
# Out:
# {'order': 'latinSquare',
#  'numSamples': 1,
#  'components': [{}, {}, {}, {}, {}, {}, {}, {}, {}]}

# %%
sizes = Config['components']

# %%
for component in sizes: 
    component['order'] = 'latinSquare'
    component['components'] = [dict() for i in range(3)]
    for stimuli in component['components']:
        stimuli['order'] = 'random'
        stimuli['components'] = ['string' for i in range(9)]

# %%
sizes
# Out:
# [{'order': 'latinSquare',
#   'components': [{'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']}]},
#  {'order': 'latinSquare',
#   'components': [{'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']}]},
#  {'order': 'latinSquare',
#   'components': [{'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']}]},
#  {'order': 'latinSquare',
#   'components': [{'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']}]},
#  {'order': 'latinSquare',
#   'components': [{'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']}]},
#  {'order': 'latinSquare',
#   'components': [{'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']}]},
#  {'order': 'latinSquare',
#   'components': [{'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']}]},
#  {'order': 'latinSquare',
#   'components': [{'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']}]},
#  {'order': 'latinSquare',
#   'components': [{'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']},
#    {'order': 'random',
#     'components': ['string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string',
#      'string']}]}]

# %%
for group, gcomponent in zip(data.keys(), Config['components']):
    print('group', group)
    for size, scomponent in zip(data[group].keys(), gcomponent['components']):
        print('size', size)
        scomponent['components'] = [f"spl_{group}_{size}_{i}" for i in range(9)]
# Out:
# group 1
# size 10
# size 25
# size 50
# group 2
# size 10
# size 25
# size 50
# group 3
# size 10
# size 25
# size 50
# group 4
# size 10
# size 25
# size 50
# group 5
# size 10
# size 25
# size 50
# group 6
# size 10
# size 25
# size 50
# group 7
# size 10
# size 25
# size 50
# group 8
# size 10
# size 25
# size 50
# group 9
# size 10
# size 25
# size 50

# %%
Config = {
    'components': [
    'introduction', 
    'consent', 
    'training',
    Config, 
    'demographics'
    ]
}

# %%
with open("public/stress-performance/assets/study-order.json", 'w') as fdata:
    json.dump(Config,fdata,indent=4)

# %%
"""
"shortest-path-1":{
    "baseComponent": "shortest-path",
    "description": "A trial for the user to click the largest bar",
    "instruction": "Click on the largest bar",
    "parameters": {
        "indices": ["1", "10", 0]
    }
},       
"""
componentdefs = dict()
for group in range(1,10):
    for size in [10,25,50]:
        for index in range(9):
            componentdefs[f'spl_{group}_{size}_{index}'] = {
                "baseComponent": "shortest-path",
                "description": "Shortest path stimulus",
                "instruction": "What is the length of the shortest path between the highlighted nodes?",
                "parameters": {
                    "indices": [group, size, index]
                }
            }

# %%
with open("public/stress-performance/assets/component_definitions.json", 'w') as fdata:
    json.dump(componentdefs,fdata,indent=4)
